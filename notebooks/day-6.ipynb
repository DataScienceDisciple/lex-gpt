# %%
from youtube_transcript_api import YouTubeTranscriptApi
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Getting transcript of the video

# %%
video_id = "eTBAxD6lt2g"
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript
# Out:
# [{'text': '- Listen, when it comes\nto romantic relationships,',
#   'start': 0.09,
#   'duration': 2.04},
#  {'text': "if it's not a hundred percent in you,",
#   'start': 2.13,
#   'duration': 2.913},
#  {'text': "it ain't happening.", 'start': 6.0, 'duration': 1.44},
#  {'text': "And I've never seen", 'start': 7.44, 'duration': 2.49},
#  {'text': 'a violation of that statement', 'start': 9.93, 'duration': 2.37},
#  {'text': "where it's like, yeah, it's\nmostly good and they're this,",
#   'start': 12.3,
#   'duration': 2.62},
#  {'text': 'and this is like the negotiations.',
#   'start': 14.92,
#   'duration': 1.91},
#  {'text': "Well, already you're, it's doomed.",
#   'start': 16.83,
#   'duration': 2.61},
#  {'text': "And that doesn't mean\nsomeone has to be perfect,",
#   'start': 19.44,
#   'duration': 1.41},
#  {'text': 'the relationship has to be perfect.',
#   'start': 20.85,
#   'duration': 1.23},
#  {'text': "But it's gotta feel a\nhundred percent inside.",
# ...
